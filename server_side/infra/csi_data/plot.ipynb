# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...

# %%
import pandas as pd

# %%
df = pd.read_json("training_data.jsonl", lines=True)

# %%
df
# Out:
#                       timestamp  esp_timestamp  rssi  \
# 0    2025-12-29 13:47:03.129905         783230   -37
# 1    2025-12-29 13:47:03.708576         783940   -38
# 2    2025-12-29 13:47:04.270240         784560   -37
# 3    2025-12-29 13:47:05.075062         785180   -38
# 4    2025-12-29 13:47:05.643151         785780   -38
# ...                         ...            ...   ...
# 1969 2025-12-29 14:18:04.379059         530970   -33
# 1970 2025-12-29 14:18:05.016072         531560   -33
# 1971 2025-12-29 14:18:05.561628         532080   -33
# 1972 2025-12-29 14:18:05.986753         532600   -33
# 1973 2025-12-29 14:18:06.514018         533130   -33
#
#                                              amplitudes  people_count  \
# 0     [134, 5, 24, 24, 24, 23, 23, 23, 23, 22, 22, 2...             0
# 1     [134, 5, 24, 23, 23, 23, 22, 22, 23, 23, 23, 2...             1
# 2     [134, 5, 28, 27, 27, 27, 26, 26, 26, 26, 26, 2...             0
# ...

# %%
mean_rsi = df['rssi'].apply(lambda x: np.mean(x))
plt.plot(mean_rsi.values)
plt.show()

# %%
rssi = df['rssi'].values
subcar = df['subcarrier_count'].values

plt.figure()
plt.plot(rssi, subcar)
plt.xlabel('RSSI')
plt.ylabel('Subcarrier Count')
plt.title('RSSI vs Subcarrier Count')
plt.show()

# %%
# Since the arrays have different shapes, we cannot simply stack them.
# Instead, we can concatenate them into one long 1D array for plotting a continuous signal.
all_amplitudes = df['subcarrier_count'].values

plt.figure(figsize=(12, 6))
plt.plot(all_amplitudes)
plt.title("Concatenated Amplitudes")
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.show()

# %%
import matplotlib.pyplot as plt
